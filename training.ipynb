# %%
# !python run_CRBPR.py --arch CRBPR --dataset Polyvore_519 --batch_size 128 --test_batch_size 128 --mode RB
# Out:
# [2024-04-29 18:29:24,782 INFO run_CRBPR.py line 190 1552537] => creating model ...
# Module already prepared, 519 users, 109339 items
# [2024-04-29 18:29:30,982 INFO run_CRBPR.py line 259 1552537] CRBPR(
#   (visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (p_visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (s_visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (s3_visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (sigmoid): Sigmoid()
#   (text_nn): Sequential(
#     (0): Linear(in_features=2400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (p_text_nn): Sequential(
#     (0): Linear(in_features=2400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (s_text_nn): Sequential(
# ...

# %%
# !python run_CRBPR.py --arch CRBPR --dataset IQON3000 --batch_size 64 --test_batch_size 64 --mode RB

# %%
# !python run_CRBPR.py --arch CRBPR --dataset Polyvore_519 --batch_size 128 --test_batch_size 128 --mode RT

# %%
# !python run_CRBPR.py --arch CRBPR --dataset IQON3000 --batch_size 64 --test_batch_size 64 --mode RT

# %%
# !python run_APCL_Polyvore_RB.py --arch GPBPR --dataset Polyvore_519 --test_batch_size 128 --mode RB
# Out:
# [2024-04-29 14:25:15,028 INFO run_APCL_Polyvore_RB.py line 200 1440448] => creating model ...
# Module already prepared, 519 users, 109339 items
# [2024-04-29 14:25:21,363 INFO run_APCL_Polyvore_RB.py line 268 1440448] GPBPR(
#   (visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (p_visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (text_nn): Sequential(
#     (0): Linear(in_features=2400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (p_text_nn): Sequential(
#     (0): Linear(in_features=2400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (bpr): BPR(
#     (user_gama): Embedding(519, 512)
#     (item_gama): Embedding(109339, 512)
#     (user_beta): Embedding(519, 1)
#     (item_beta): Embedding(109339, 1)
#   )
#   (vtbpr): VTBPR(
#     (user_gama): Embedding(519, 512)
#     (item_gama): Embedding(109339, 512)
# ...

# %%
# !python run_APCL_Polyvore_RB.py --arch GPBPR --dataset IQON3000 --test_batch_size 64
# Out:
# [2024-04-26 22:42:42,820 INFO run_APCL_Polyvore_RB.py line 200 3779473] => creating model ...
# Module already prepared, 3236 users, 142737 items
# 2024-04-26 22:42:57.938782: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-04-26 22:42:57.942495: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-26 22:42:57.979187: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python run_APCL_Polyvore_RB.py --arch GPBPR --dataset IQON3000 --test_batch_size 64 --mode RT
# Out:
# [2024-04-26 22:55:30,861 INFO run_APCL_Polyvore_RB.py line 200 3791510] => creating model ...
# Module already prepared, 3236 users, 142737 items
# [2024-04-26 22:55:48,714 INFO run_APCL_Polyvore_RB.py line 248 3791510] GPBPR(
#   (visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (p_visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (text_nn): Sequential(
#     (0): Linear(in_features=400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (p_text_nn): Sequential(
#     (0): Linear(in_features=400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (text_embedding): Embedding(54276, 300)
#   (textcnn): TextCNN(
#     (text_cnn): ModuleList(
#       (0): Sequential(
#         (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#         (1): Sigmoid()
# ...

# %%
# !python run_APCL_Polyvore_RB.py --arch GPBPR --dataset Polyvore_519 --test_batch_size 128 --mode RT
# Out:
# [2024-04-26 23:11:14,673 INFO run_APCL_Polyvore_RB.py line 200 3807751] => creating model ...
# Module already prepared, 519 users, 109339 items
# [2024-04-26 23:11:21,222 INFO run_APCL_Polyvore_RB.py line 261 3807751] GPBPR(
#   (visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (p_visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (text_nn): Sequential(
#     (0): Linear(in_features=2400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (p_text_nn): Sequential(
#     (0): Linear(in_features=2400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (bpr): BPR(
#     (user_gama): Embedding(519, 512)
#     (item_gama): Embedding(109339, 512)
#     (user_beta): Embedding(519, 1)
#     (item_beta): Embedding(109339, 1)
#   )
#   (vtbpr): VTBPR(
#     (user_gama): Embedding(519, 512)
#     (item_gama): Embedding(109339, 512)
# ...

# %%
# !python run_APCL_Polyvore_RB.py --arch APCL --dataset Polyvore_519 --test_batch_size 128 --mode RB
# Out:
# [2024-04-26 23:44:44,520 INFO run_APCL_Polyvore_RB.py line 200 3839725] => creating model ...
# Module already prepared, 519 users, 109339 items
# [2024-04-26 23:44:51,271 INFO run_APCL_Polyvore_RB.py line 267 3839725] APCL(
#   (visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (p_visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (att_visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (text_nn): Sequential(
#     (0): Linear(in_features=2400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (p_text_nn): Sequential(
#     (0): Linear(in_features=2400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (att_text_nn): Sequential(
#     (0): Linear(in_features=2400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (V_attention): SelfAttention(
# ...

# %%
# !python run_APCL_Polyvore_RB.py --arch APCL --dataset Polyvore_519 --test_batch_size 128 --mode RT
# Out:
# [2024-04-26 23:48:49,654 INFO run_APCL_Polyvore_RB.py line 200 3842445] => creating model ...
# Module already prepared, 519 users, 109339 items
# [2024-04-26 23:48:57,028 INFO run_APCL_Polyvore_RB.py line 267 3842445] APCL(
#   (visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (p_visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (att_visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (text_nn): Sequential(
#     (0): Linear(in_features=2400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (p_text_nn): Sequential(
#     (0): Linear(in_features=2400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (att_text_nn): Sequential(
#     (0): Linear(in_features=2400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (V_attention): SelfAttention(
# ...

# %%
# !python run_APCL_Polyvore_RB.py --arch APCL --dataset IQON3000 --test_batch_size 64 --mode RB
# Out:
# [2024-04-26 23:51:37,386 INFO run_APCL_Polyvore_RB.py line 200 3844494] => creating model ...
# Module already prepared, 3236 users, 142737 items
# [2024-04-26 23:51:53,171 INFO run_APCL_Polyvore_RB.py line 267 3844494] APCL(
#   (visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (p_visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (att_visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (text_nn): Sequential(
#     (0): Linear(in_features=400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (p_text_nn): Sequential(
#     (0): Linear(in_features=400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (att_text_nn): Sequential(
#     (0): Linear(in_features=400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (V_attention): SelfAttention(
# ...

# %%
# !python run_APCL_Polyvore_RB.py --arch APCL --dataset IQON3000 --test_batch_size 64 --mode RT
# Out:
# [2024-04-27 00:10:34,463 INFO run_APCL_Polyvore_RB.py line 200 3863705] => creating model ...
# Module already prepared, 3236 users, 142737 items
# [2024-04-27 00:10:51,620 INFO run_APCL_Polyvore_RB.py line 268 3863705] APCL(
#   (visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (p_visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (att_visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (text_nn): Sequential(
#     (0): Linear(in_features=400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (p_text_nn): Sequential(
#     (0): Linear(in_features=400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (att_text_nn): Sequential(
#     (0): Linear(in_features=400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (V_attention): SelfAttention(
# ...

# %%
# !python run_APCL_Polyvore_RB.py --arch VTBPR --dataset Polyvore_519 --test_batch_size 128 --mode RB
# Out:
# [2024-04-29 00:12:19,287 INFO run_APCL_Polyvore_RB.py line 200 1200914] => creating model ...
# Module already prepared, 519 users, 109339 items
# [2024-04-29 00:12:25,637 INFO run_APCL_Polyvore_RB.py line 268 1200914] GPBPR(
#   (visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (p_visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (text_nn): Sequential(
#     (0): Linear(in_features=2400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (p_text_nn): Sequential(
#     (0): Linear(in_features=2400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (bpr): BPR(
#     (user_gama): Embedding(519, 512)
#     (item_gama): Embedding(109339, 512)
#     (user_beta): Embedding(519, 1)
#     (item_beta): Embedding(109339, 1)
#   )
#   (vtbpr): VTBPR(
#     (user_gama): Embedding(519, 512)
#     (item_gama): Embedding(109339, 512)
# ...

# %%
# !python run_APCL_Polyvore_RB.py --arch VTBPR --dataset Polyvore_519 --test_batch_size 128 --mode RT
# Out:
# [2024-04-29 00:13:38,149 INFO run_APCL_Polyvore_RB.py line 200 1201542] => creating model ...
# Module already prepared, 519 users, 109339 items
# [2024-04-29 00:13:44,847 INFO run_APCL_Polyvore_RB.py line 268 1201542] GPBPR(
#   (visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (p_visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (text_nn): Sequential(
#     (0): Linear(in_features=2400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (p_text_nn): Sequential(
#     (0): Linear(in_features=2400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (bpr): BPR(
#     (user_gama): Embedding(519, 512)
#     (item_gama): Embedding(109339, 512)
#     (user_beta): Embedding(519, 1)
#     (item_beta): Embedding(109339, 1)
#   )
#   (vtbpr): VTBPR(
#     (user_gama): Embedding(519, 512)
#     (item_gama): Embedding(109339, 512)
# ...

# %%
# !python run_APCL_Polyvore_RB.py --arch VTBPR --dataset IQON3000 --test_batch_size 64 --mode RB
# Out:
# [2024-04-29 00:15:05,019 INFO run_APCL_Polyvore_RB.py line 200 1202159] => creating model ...
# Module already prepared, 3236 users, 142737 items
# [2024-04-29 00:15:20,163 INFO run_APCL_Polyvore_RB.py line 268 1202159] GPBPR(
#   (visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (p_visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (text_nn): Sequential(
#     (0): Linear(in_features=400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (p_text_nn): Sequential(
#     (0): Linear(in_features=400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (text_embedding): Embedding(54276, 300)
#   (textcnn): TextCNN(
#     (text_cnn): ModuleList(
#       (0): Sequential(
#         (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#         (1): Sigmoid()
# ...

# %%
# !python run_APCL_Polyvore_RB.py --arch VTBPR --dataset IQON3000 --test_batch_size 64 --mode RT
# Out:
# [2024-04-29 00:31:25,460 INFO run_APCL_Polyvore_RB.py line 200 1209469] => creating model ...
# Module already prepared, 3236 users, 142737 items
# [2024-04-29 00:31:42,632 INFO run_APCL_Polyvore_RB.py line 268 1209469] GPBPR(
#   (visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (p_visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (text_nn): Sequential(
#     (0): Linear(in_features=400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (p_text_nn): Sequential(
#     (0): Linear(in_features=400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (text_embedding): Embedding(54276, 300)
#   (textcnn): TextCNN(
#     (text_cnn): ModuleList(
#       (0): Sequential(
#         (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#         (1): Sigmoid()
# ...

# %%
# !python run_APCL_Polyvore_RB.py --arch BPR --dataset Polyvore_519 --test_batch_size 128 --mode RB
# Out:
# [2024-04-29 15:04:50,336 INFO run_APCL_Polyvore_RB.py line 200 1454362] => creating model ...
# Module already prepared, 519 users, 109339 items
# [2024-04-29 15:04:57,428 INFO run_APCL_Polyvore_RB.py line 268 1454362] GPBPR(
#   (visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (p_visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (text_nn): Sequential(
#     (0): Linear(in_features=2400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (p_text_nn): Sequential(
#     (0): Linear(in_features=2400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (bpr): BPR(
#     (user_gama): Embedding(519, 512)
#     (item_gama): Embedding(109339, 512)
#     (user_beta): Embedding(519, 1)
#     (item_beta): Embedding(109339, 1)
#   )
#   (vtbpr): VTBPR(
#     (user_gama): Embedding(519, 512)
#     (item_gama): Embedding(109339, 512)
# ...

# %%
# !python run_APCL_Polyvore_RB.py --arch BPR --dataset Polyvore_519 --test_batch_size 128 --mode RT
# Out:
# [2024-04-29 15:08:08,406 INFO run_APCL_Polyvore_RB.py line 200 1455650] => creating model ...
# Module already prepared, 519 users, 109339 items
# [2024-04-29 15:08:14,761 INFO run_APCL_Polyvore_RB.py line 268 1455650] GPBPR(
#   (visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (p_visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (text_nn): Sequential(
#     (0): Linear(in_features=2400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (p_text_nn): Sequential(
#     (0): Linear(in_features=2400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (bpr): BPR(
#     (user_gama): Embedding(519, 512)
#     (item_gama): Embedding(109339, 512)
#     (user_beta): Embedding(519, 1)
#     (item_beta): Embedding(109339, 1)
#   )
#   (vtbpr): VTBPR(
#     (user_gama): Embedding(519, 512)
#     (item_gama): Embedding(109339, 512)
# ...

# %%
# !python run_APCL_Polyvore_RB.py --arch BPR --dataset IQON3000 --test_batch_size 64 --mode RB
# Out:
# [2024-04-27 01:18:35,201 INFO run_APCL_Polyvore_RB.py line 200 3940064] => creating model ...
# Module already prepared, 3236 users, 142737 items
# [2024-04-27 01:18:52,259 INFO run_APCL_Polyvore_RB.py line 268 3940064] GPBPR(
#   (visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (p_visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (text_nn): Sequential(
#     (0): Linear(in_features=400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (p_text_nn): Sequential(
#     (0): Linear(in_features=400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (text_embedding): Embedding(54276, 300)
#   (textcnn): TextCNN(
#     (text_cnn): ModuleList(
#       (0): Sequential(
#         (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#         (1): Sigmoid()
# ...

# %%
# !python run_APCL_Polyvore_RB.py --arch BPR --dataset IQON3000 --test_batch_size 64 --mode RT
# Out:
# [2024-04-29 15:10:24,413 INFO run_APCL_Polyvore_RB.py line 200 1456545] => creating model ...
# Module already prepared, 3236 users, 142737 items
# [2024-04-29 15:10:40,235 INFO run_APCL_Polyvore_RB.py line 268 1456545] GPBPR(
#   (visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (p_visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (text_nn): Sequential(
#     (0): Linear(in_features=400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (p_text_nn): Sequential(
#     (0): Linear(in_features=400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (text_embedding): Embedding(54276, 300)
#   (textcnn): TextCNN(
#     (text_cnn): ModuleList(
#       (0): Sequential(
#         (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#         (1): Sigmoid()
# ...

# %%
# !python run_APCL_Polyvore_RB.py --arch VBPR --dataset Polyvore_519 --test_batch_size 128 --mode RB
# Out:
# [2024-04-29 00:48:06,538 INFO run_APCL_Polyvore_RB.py line 200 1216775] => creating model ...
# Module already prepared, 519 users, 109339 items
# [2024-04-29 00:48:13,582 INFO run_APCL_Polyvore_RB.py line 268 1216775] GPBPR(
#   (visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (p_visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (text_nn): Sequential(
#     (0): Linear(in_features=2400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (p_text_nn): Sequential(
#     (0): Linear(in_features=2400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (bpr): BPR(
#     (user_gama): Embedding(519, 512)
#     (item_gama): Embedding(109339, 512)
#     (user_beta): Embedding(519, 1)
#     (item_beta): Embedding(109339, 1)
#   )
#   (vtbpr): VTBPR(
#     (user_gama): Embedding(519, 512)
#     (item_gama): Embedding(109339, 512)
# ...

# %%
# !python run_APCL_Polyvore_RB.py --arch VBPR --dataset Polyvore_519 --test_batch_size 128 --mode RT
# Out:
# [2024-04-29 00:51:29,632 INFO run_APCL_Polyvore_RB.py line 200 1218108] => creating model ...
# Module already prepared, 519 users, 109339 items
# [2024-04-29 00:51:36,325 INFO run_APCL_Polyvore_RB.py line 268 1218108] GPBPR(
#   (visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (p_visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (text_nn): Sequential(
#     (0): Linear(in_features=2400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (p_text_nn): Sequential(
#     (0): Linear(in_features=2400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (bpr): BPR(
#     (user_gama): Embedding(519, 512)
#     (item_gama): Embedding(109339, 512)
#     (user_beta): Embedding(519, 1)
#     (item_beta): Embedding(109339, 1)
#   )
#   (vtbpr): VTBPR(
#     (user_gama): Embedding(519, 512)
#     (item_gama): Embedding(109339, 512)
# ...

# %%
# !python run_APCL_Polyvore_RB.py --arch VBPR --dataset IQON3000 --test_batch_size 64 --mode RB
# Out:
# [2024-04-29 00:53:20,255 INFO run_APCL_Polyvore_RB.py line 200 1218856] => creating model ...
# Module already prepared, 3236 users, 142737 items
# [2024-04-29 00:53:36,844 INFO run_APCL_Polyvore_RB.py line 268 1218856] GPBPR(
#   (visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (p_visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (text_nn): Sequential(
#     (0): Linear(in_features=400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (p_text_nn): Sequential(
#     (0): Linear(in_features=400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (text_embedding): Embedding(54276, 300)
#   (textcnn): TextCNN(
#     (text_cnn): ModuleList(
#       (0): Sequential(
#         (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#         (1): Sigmoid()
# ...

# %%
# !python run_APCL_Polyvore_RB.py --arch VBPR --dataset IQON3000 --test_batch_size 64 --mode RT
# Out:
# [2024-04-29 01:03:21,165 INFO run_APCL_Polyvore_RB.py line 200 1222584] => creating model ...
# Module already prepared, 3236 users, 142737 items
# [2024-04-29 01:03:38,735 INFO run_APCL_Polyvore_RB.py line 268 1222584] GPBPR(
#   (visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (p_visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (text_nn): Sequential(
#     (0): Linear(in_features=400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (p_text_nn): Sequential(
#     (0): Linear(in_features=400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (text_embedding): Embedding(54276, 300)
#   (textcnn): TextCNN(
#     (text_cnn): ModuleList(
#       (0): Sequential(
#         (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#         (1): Sigmoid()
# ...

# %%
# !python run_APCL_Polyvore_RB.py --arch TBPR --dataset Polyvore_519 --test_batch_size 128 --mode RB
# Out:
# [2024-04-29 01:15:47,768 INFO run_APCL_Polyvore_RB.py line 200 1228028] => creating model ...
# Module already prepared, 519 users, 109339 items
# [2024-04-29 01:15:54,208 INFO run_APCL_Polyvore_RB.py line 268 1228028] GPBPR(
#   (visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (p_visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (text_nn): Sequential(
#     (0): Linear(in_features=2400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (p_text_nn): Sequential(
#     (0): Linear(in_features=2400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (bpr): BPR(
#     (user_gama): Embedding(519, 512)
#     (item_gama): Embedding(109339, 512)
#     (user_beta): Embedding(519, 1)
#     (item_beta): Embedding(109339, 1)
#   )
#   (vtbpr): VTBPR(
#     (user_gama): Embedding(519, 512)
#     (item_gama): Embedding(109339, 512)
# ...

# %%
# !python run_APCL_Polyvore_RB.py --arch TBPR --dataset Polyvore_519 --test_batch_size 128 --mode RT
# Out:
# [2024-04-29 01:17:08,716 INFO run_APCL_Polyvore_RB.py line 200 1228616] => creating model ...
# Module already prepared, 519 users, 109339 items
# [2024-04-29 01:17:15,955 INFO run_APCL_Polyvore_RB.py line 268 1228616] GPBPR(
#   (visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (p_visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (text_nn): Sequential(
#     (0): Linear(in_features=2400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (p_text_nn): Sequential(
#     (0): Linear(in_features=2400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (bpr): BPR(
#     (user_gama): Embedding(519, 512)
#     (item_gama): Embedding(109339, 512)
#     (user_beta): Embedding(519, 1)
#     (item_beta): Embedding(109339, 1)
#   )
#   (vtbpr): VTBPR(
#     (user_gama): Embedding(519, 512)
#     (item_gama): Embedding(109339, 512)
# ...

# %%
# !python run_APCL_Polyvore_RB.py --arch TBPR --dataset IQON3000 --test_batch_size 64 --mode RB
# Out:
# [2024-04-29 01:19:22,961 INFO run_APCL_Polyvore_RB.py line 200 1229540] => creating model ...
# Module already prepared, 3236 users, 142737 items
# [2024-04-29 01:19:39,449 INFO run_APCL_Polyvore_RB.py line 268 1229540] GPBPR(
#   (visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (p_visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (text_nn): Sequential(
#     (0): Linear(in_features=400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (p_text_nn): Sequential(
#     (0): Linear(in_features=400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (text_embedding): Embedding(54276, 300)
#   (textcnn): TextCNN(
#     (text_cnn): ModuleList(
#       (0): Sequential(
#         (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#         (1): Sigmoid()
# ...

# %%
# !python run_APCL_Polyvore_RB.py --arch TBPR --dataset IQON3000 --test_batch_size 64 --mode RT
# Out:
# [2024-04-29 01:27:42,709 INFO run_APCL_Polyvore_RB.py line 200 1232653] => creating model ...
# Module already prepared, 3236 users, 142737 items
# [2024-04-29 01:27:59,263 INFO run_APCL_Polyvore_RB.py line 268 1232653] GPBPR(
#   (visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (p_visual_nn): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (text_nn): Sequential(
#     (0): Linear(in_features=400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (p_text_nn): Sequential(
#     (0): Linear(in_features=400, out_features=512, bias=True)
#     (1): Sigmoid()
#   )
#   (text_embedding): Embedding(54276, 300)
#   (textcnn): TextCNN(
#     (text_cnn): ModuleList(
#       (0): Sequential(
#         (0): Conv2d(1, 100, kernel_size=(2, 300), stride=(1, 1))
#         (1): Sigmoid()
# ...
